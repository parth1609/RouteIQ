# %%
from datetime import date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('aa_dataset-tickets-multi-lang.csv')
df1=df1[df1['language']=='en']
df1.head(2)
# Out:
#                                              subject  \
# 1                                 Account Disruption
# 2  Query About Smart Home System Integration Feat...
#
#                                                 body  \
# 1  Dear Customer Support Team,\n\nI am writing to...
# 2  Dear Customer Support Team,\n\nI hope this mes...
#
#                                               answer      type  \
# 1  Thank you for reaching out, <name>. We are awa...  Incident
# 2  Thank you for your inquiry. Our products suppo...   Request
#
#                    queue priority language  version    tag_1       tag_2  \
# 1      Technical Support     high       en       51  Account  Disruption
# 2  Returns and Exchanges   medium       en       51  Product     Feature
#
#           tag_3 tag_4         tag_5 tag_6 tag_7 tag_8
# 1        Outage    IT  Tech Support   NaN   NaN   NaN
# 2  Tech Support   NaN           NaN   NaN   NaN   NaN

# %%
tags = df1[['tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6']]
tags
# Out:
#              tag_1          tag_2          tag_3          tag_4         tag_5  \
# 1          Account     Disruption         Outage             IT  Tech Support
# 2          Product        Feature   Tech Support            NaN           NaN
# 3          Billing        Payment        Account  Documentation      Feedback
# 4          Product        Feature       Feedback   Tech Support           NaN
# 5          Feature        Product  Documentation       Feedback           NaN
# ...            ...            ...            ...            ...           ...
# 28578      Billing        Payment    Performance            Bug           NaN
# 28580     Security       Incident            Bug    Performance           NaN
# 28582  Performance             IT   Tech Support            NaN           NaN
# 28585      Feature             IT   Tech Support            NaN           NaN
# 28586      Feature  Documentation       Feedback             IT           NaN
#
#       tag_6
# 1       NaN
# ...

# %%
row_tags = tags.apply(lambda row: [tag for tag in row if pd.notna(tag)],axis=1)
df1['tags_'] = pd.DataFrame(row_tags)

# %%
df1 = df1[['body','queue','priority','tags_']]
df1.head()
# Out:
#                                                 body                  queue  \
# 1  Dear Customer Support Team,\n\nI am writing to...      Technical Support
# 2  Dear Customer Support Team,\n\nI hope this mes...  Returns and Exchanges
# 3  Dear Customer Support Team,\n\nI hope this mes...   Billing and Payments
# 4  Dear Support Team,\n\nI hope this message reac...    Sales and Pre-Sales
# 5  Dear Customer Support,\n\nI hope this message ...      Technical Support
#
#   priority                                              tags_
# 1     high    [Account, Disruption, Outage, IT, Tech Support]
# 2   medium                   [Product, Feature, Tech Support]
# 3      low  [Billing, Payment, Account, Documentation, Fee...
# 4   medium         [Product, Feature, Feedback, Tech Support]
# 5     high        [Feature, Product, Documentation, Feedback]

# %%
df1.iloc[0]['body']
# Out:
# 'Dear Customer Support Team,\\n\\nI am writing to report a significant problem with the centralized account management portal, which currently appears to be offline. This outage is blocking access to account settings, leading to substantial inconvenience. I have attempted to log in multiple times using different browsers and devices, but the issue persists.\\n\\nCould you please provide an update on the outage status and an estimated time for resolution? Also, are there any alternative ways to access and manage my account during this downtime?'

# %%
df1['body'] = df1['body'].str.replace('\\n', '', regex=False)

# %%
df1
# Out:
#                                                     Body  \
# 1      Dear Customer Support Team,I am writing to rep...
# 2      Dear Customer Support Team,I hope this message...
# 3      Dear Customer Support Team,I hope this message...
# 4      Dear Support Team,I hope this message reaches ...
# 5      Dear Customer Support,I hope this message reac...
# ...                                                  ...
# 28578  An unexpected billing discrepancy has been not...
# 28580  A data breach has occurred, which might be rel...
# 28582  The data analytics tool experiences sluggish p...
# 28585  Requesting an update on the integration featur...
# 28586  Looking for detailed information on the projec...
#
#                   Department Priority  \
# 1          Technical Support     high
# 2      Returns and Exchanges   medium
# 3       Billing and Payments      low
# 4        Sales and Pre-Sales   medium
# 5          Technical Support     high
# ...                      ...      ...
# ...

# %%
df1.iloc[1]['body']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\parth\OneDrive\Desktop\one\gradient descent\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'body'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ...

# %%
df1.rename(columns={'body': 'Body',
                   'queue': 'Department',  
                   'priority': 'Priority',  
                   'tags_': 'Tags'},
          inplace=True)

# %%
df1.head()
# Out:
#                                                 Body             Department  \
# 1  Dear Customer Support Team,I am writing to rep...      Technical Support
# 2  Dear Customer Support Team,I hope this message...  Returns and Exchanges
# 3  Dear Customer Support Team,I hope this message...   Billing and Payments
# 4  Dear Support Team,I hope this message reaches ...    Sales and Pre-Sales
# 5  Dear Customer Support,I hope this message reac...      Technical Support
#
#   Priority                                               Tags
# 1     high    [Account, Disruption, Outage, IT, Tech Support]
# 2   medium                   [Product, Feature, Tech Support]
# 3      low  [Billing, Payment, Account, Documentation, Fee...
# 4   medium         [Product, Feature, Feedback, Tech Support]
# 5     high        [Feature, Product, Documentation, Feedback]

# %%
df1.to_csv("data1.csv",index=False)

# %%
df2 = pd.read_csv('dataset-tickets-multi-lang-4-20k.csv')

# %%
df2=df2[df2['language']=='en']
df2
# Out:
#                                                  subject  \
# 1                               Customer Support Inquiry
# 2                          Data Analytics for Investment
# 4                                               Security
# 5      Concerns About Securing Medical Data on 2-in-1...
# 7                               Problem with Integration
# ...                                                  ...
# 19992  Guidelines for Securing Medical Data in OBS St...
# 19993                                                NaN
# 19994                 Support for Marketing Enhancements
# 19995     Assistance Needed for IFTTT Docker Integration
# 19997                                                NaN
#
#                                                     body  \
# 1      Seeking information on digital strategies that...
# 2      I am contacting you to request information on ...
# 4      Dear Customer Support, I am reaching out to in...
# ...

# %%
tags2 = df2[['tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6', 'tag_7', 'tag_8']]

# %%
tags2.isnull().sum()
# Out:
# tag_1        0
# tag_2       10
# tag_3       44
# tag_4      873
# tag_5     4038
# tag_6     7385
# tag_7     9358
# tag_8    10596
# dtype: int64

# %%
row_tags2 = tags2.apply(lambda row: [tag for tag in row if pd.notna(tag)],axis=1)
df2['tags_'] = pd.DataFrame(row_tags2)

# %%
df2
# Out:
#                                                  subject  \
# 1                               Customer Support Inquiry
# 2                          Data Analytics for Investment
# 4                                               Security
# 5      Concerns About Securing Medical Data on 2-in-1...
# 7                               Problem with Integration
# ...                                                  ...
# 19992  Guidelines for Securing Medical Data in OBS St...
# 19993                                                NaN
# 19994                 Support for Marketing Enhancements
# 19995     Assistance Needed for IFTTT Docker Integration
# 19997                                                NaN
#
#                                                     body  \
# 1      Seeking information on digital strategies that...
# 2      I am contacting you to request information on ...
# 4      Dear Customer Support, I am reaching out to in...
# ...

# %%
df2 = df2[['body','queue','priority','tags_']]
df2.head()
# Out:
#                                                 body              queue  \
# 1  Seeking information on digital strategies that...   Customer Service
# 2  I am contacting you to request information on ...   Customer Service
# 4  Dear Customer Support, I am reaching out to in...   Customer Service
# 5  Inquiring about best practices for securing me...  Technical Support
# 7  The integration stopped working unexpectedly, ...         IT Support
#
#   priority                                              tags_
# 1   medium                [Feedback, Sales, IT, Tech Support]
# 2   medium  [Technical, Product, Guidance, Documentation, ...
# 4   medium  [Security, Customer, Compliance, Breach, Docum...
# 5   medium     [Security, Product, Feature, IT, Tech Support]
# 7     high  [Technical, Integration, Bug, Resolution, Outa...

# %%
df2.iloc[10000]['body']
# Out:
# 'There has been a possible data breach due to an outdated software vulnerability. Antivirus scans were performed, and firewalls were checked.'

# %%
df2['body'] = df2['body'].str.replace('\\n', '', regex=False)
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_17104\1683119070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['body'] = df2['body'].str.replace('\\n', '', regex=False)

# %%
df1.isnull().sum()
# Out:
# Body          0
# Department    0
# Priority      0
# Tags          0
# dtype: int64

# %%
df2.dropna(inplace=True)
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_17104\1761232742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)

# %%
df2.isnull().sum()
# Out:
# body        0
# queue       0
# priority    0
# tags_       0
# dtype: int64

# %%
df1
# Out:
#                                                     Body  \
# 1      Dear Customer Support Team,I am writing to rep...
# 2      Dear Customer Support Team,I hope this message...
# 3      Dear Customer Support Team,I hope this message...
# 4      Dear Support Team,I hope this message reaches ...
# 5      Dear Customer Support,I hope this message reac...
# ...                                                  ...
# 28578  An unexpected billing discrepancy has been not...
# 28580  A data breach has occurred, which might be rel...
# 28582  The data analytics tool experiences sluggish p...
# 28585  Requesting an update on the integration featur...
# 28586  Looking for detailed information on the projec...
#
#                   Department Priority  \
# 1          Technical Support     high
# 2      Returns and Exchanges   medium
# 3       Billing and Payments      low
# 4        Sales and Pre-Sales   medium
# 5          Technical Support     high
# ...                      ...      ...
# ...

# %%
df2.rename(columns={'body': 'Body',
                   'queue': 'Department',  
                   'priority': 'Priority',  
                   'tags_': 'Tags'},
          inplace=True)
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_17104\2732223564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={'body': 'Body',

# %%
main_df = pd.concat([df1, df2], ignore_index=True)

# %%
main_df.shape
# Out:
# (28260, 4)

# %%
df3 = pd.read_csv('dataset-tickets-multi-lang3-4k.csv')
df3=df3[df3['language']=='en']
df3.head()
# Out:
#                                               subject  \
# 3             Urgent Assistance Required: AWS Service
# 5      Urgent: Issue with Zoom Screen Sharing Feature
# 7   Service outage resolution requested for ongoin...
# 8                                 Surface Pro 7 Issue
# 10  Request for software development consultation ...
#
#                                                  body  \
# 3   Dear IT Services Support Team, \n\nI am reachi...
# 5   Dear Customer Support,\n\nI am experiencing a ...
# 7   Dear IT Services Customer Support,\n\nI am wri...
# 8   Dear Tech Online Store Support Team,\n\nI hope...
# 10  Dear Customer Support,\n\nI hope this message ...
#
#                                                answer      type  \
# 3   Dear <name>,\n\nThank you for reaching out reg...   Request
# 5   Dear <name>,\n\nThank you for reaching out. We...  Incident
# 7   Dear <name>,\n\nThank you for reaching out to ...    Change
# ...

# %%
tags3 = df3[['tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6', 'tag_7', 'tag_8','tag_9']]
tags3.head()
# Out:
#                 tag_1               tag_2                 tag_3  \
# 3          IT Support        Urgent Issue  Service Notification
# 5   Technical Support        Urgent Issue    Service Disruption
# 7      Service Outage          IT Support    Problem Resolution
# 8   Technical Support     Product Support          Software Bug
# 10         IT Support  Technical Guidance    Problem Resolution
#
#                    tag_4               tag_5               tag_6  \
# 3         Cloud Services  Problem Resolution  Technical Guidance
# 5     Problem Resolution        Software Bug                 NaN
# 7      Technical Support    Service Recovery  System Maintenance
# 8       Hardware Failure  Problem Resolution    Service Recovery
# 10  Service Notification        Urgent Issue                 NaN
#
#                  tag_7         tag_8  tag_9
# 3   Performance Tuning           NaN    NaN
# 5                  NaN           NaN    NaN
# 7   Performance Tuning  Urgent Issue    NaN
# ...

# %%
row_tags3 = tags3.apply(lambda row: [tag for tag in row if pd.notna(tag)],axis=1)
df3['tags_'] = pd.DataFrame(row_tags3)

# %%
df3 = df3[['body','queue','priority','tags_']]
df3.head()
# Out:
#                                                  body  \
# 3   Dear IT Services Support Team, \n\nI am reachi...
# 5   Dear Customer Support,\n\nI am experiencing a ...
# 7   Dear IT Services Customer Support,\n\nI am wri...
# 8   Dear Tech Online Store Support Team,\n\nI hope...
# 10  Dear Customer Support,\n\nI hope this message ...
#
#                               queue priority  \
# 3                        IT Support     high
# 5                 Technical Support     high
# 7   Service Outages and Maintenance     high
# 8                   Product Support   medium
# 10                Technical Support   medium
#
#                                                 tags_
# 3   [IT Support, Urgent Issue, Service Notificatio...
# 5   [Technical Support, Urgent Issue, Service Disr...
# 7   [Service Outage, IT Support, Problem Resolutio...
# 8   [Technical Support, Product Support, Software ...
# 10  [IT Support, Technical Guidance, Problem Resol...

# %%
df3.shape
# Out:
# (1391, 4)

# %%
df3.iloc[1000]['body']
# Out:
# 'Hello <name>, I am contacting you regarding a problem with the battery of my MacBook Air M1. Kindly address this matter at your earliest opportunity. My account number is <acc_num>. I appreciate your quick attention to this issue.'

# %%
df3['body'] = df3['body'].str.replace('<', '', regex=False)
df3['body'] = df3['body'].str.replace('>', '', regex=False)

# %%
df3.iloc[0]['body']
# Out:
# 'Dear IT Services Support Team, \n\nI am reaching out regarding a high-priority ticket related to our AWS Management Service. We are experiencing significant challenges in deploying services and optimizing our cloud infrastructure costs. It is crucial for us to gain clarity and efficient solutions on this matter. \n\nWe have been noticing higher-than-expected expenditure, and the deployment process appears to have several hurdles that prevent smooth operation. As this is affecting our operational efficiency and financial planning, your expert assistance is urgently requested. \n\nCould you please prioritize this ticket and guide us on the best practices to streamline deployment and manage costs effectively on AWS? Your prompt response will greatly aid in mitigating potential losses and optimizing current systems. \n\nThank you for your immediate attention and expertise.\n\nBest regards, \n\nname\nacc_num\nname@example.com\ntel_num'

# %%
df3['body'] = df3['body'].str.replace('\n', '', regex=False)

# %%
df3
# Out:
#                                                    body  \
# 3     Dear IT Services Support Team, I am reaching o...
# 5     Dear Customer Support,I am experiencing a high...
# 7     Dear IT Services Customer Support,I am writing...
# 8     Dear Tech Online Store Support Team,I hope thi...
# 10    Dear Customer Support,I hope this message find...
# ...                                                 ...
# 3984  Hello Customer Support Team,My name is name. I...
# 3985  Dear Customer Support Team,We are currently en...
# 3986  Dear Customer Support Team,Our Cisco Router IS...
# 3990  Dear IT Services Support Team, I am writing to...
# 3999  Dear Tech Online Store Customer Support,I rece...
#
#                                 queue priority  \
# 3                          IT Support     high
# 5                   Technical Support     high
# 7     Service Outages and Maintenance     high
# 8                     Product Support   medium
# 10                  Technical Support   medium
# ...

# %%
df3['body'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df3
# Out:
#                                                    body  \
# 3     Dear IT Services Support Team, I am reaching o...
# 5     Dear Customer Support,I am experiencing a high...
# 7     Dear IT Services Customer Support,I am writing...
# 8     Dear Tech Online Store Support Team,I hope thi...
# 10    Dear Customer Support,I hope this message find...
# ...                                                 ...
# 3984  Hello Customer Support Team,My name is name. I...
# 3985  Dear Customer Support Team,We are currently en...
# 3986  Dear Customer Support Team,Our Cisco Router IS...
# 3990  Dear IT Services Support Team, I am writing to...
# 3999  Dear Tech Online Store Customer Support,I rece...
#
#                                 queue priority  \
# 3                          IT Support     high
# 5                   Technical Support     high
# 7     Service Outages and Maintenance     high
# 8                     Product Support   medium
# 10                  Technical Support   medium
# ...

# %%
df3.rename(columns={'body': 'Body',
                   'queue': 'Department',  
                   'priority': 'Priority',  
                   'tags_': 'Tags'},
          inplace=True)

# %%
main_df = pd.concat([df1, df2,df3], ignore_index=True)

# %%
main_df.isnull().sum()
# Out:
# Body          1
# Department    0
# Priority      0
# Tags          0
# dtype: int64

# %%
main_df.iloc[25001]['Body']
# Out:
# 'I am seeking details on the various features and customization options available within the project management SaaS platform. Could you provide comprehensive information on the tools and functionalities that the platform offers? This would greatly assist me in tailoring the platform to meet our specific project management needs. Your information will help me better understand the platform and its suitability for our requirements.'

# %%
main_df.iloc[25001]['Department']
# Out:
# 'Product Support'

# %%
main_df.iloc[25001]['Tags']
# Out:
# ['Feature', 'Documentation', 'Feedback', 'IT', 'Tech Support']

# %%
main_df.iloc[20000]['Priority']
# Out:
# 'medium'

# %%
main_df.to_csv('IT_support_data.csv')

# %%
import csv
import json

def csv_to_json_no_index(csv_filepath, json_filepath):
    data = []
    with open(csv_filepath, 'r', encoding='utf-8') as csv_file:
        # csv.DictReader reads the first row as headers and maps subsequent rows to dictionaries
        csv_reader = csv.DictReader(csv_file)
        for row in csv_reader:
            # If there's an empty string key (common for unnamed first column in some CSVs)
            # you can explicitly remove it here if it appears, although DictReader usually prevents it
            # if the header isn't actually blank in the CSV itself.
            if "" in row:
                del row[""] # This line removes the empty key if it exists
            data.append(row)

    with open(json_filepath, 'w', encoding='utf-8') as json_file:
        json.dump(data, json_file, indent=4)

    print(f"CSV data from '{csv_filepath}' successfully converted to JSON in '{json_filepath}' without an index column.")

# Usage
csv_file = 'IT Support Ticket Data.csv'
json_file = 'IT Support Ticket Data.json'
csv_to_json_no_index(csv_file, json_file)
# Out:
# CSV data from 'IT Support Ticket Data.csv' successfully converted to JSON in 'IT Support Ticket Data.json' without an index column.
